# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense

# Load dataset
data = pd.read_csv("weatherHistory.csv")
temp = data['Temperature (C)'].values.reshape(-1,1)

# Scale
scaler = MinMaxScaler()
temp = scaler.fit_transform(temp)

# Create sequences
X, y = [], []
for i in range(10, len(temp)):
    X.append(temp[i-10:i])
    y.append(temp[i])

X, y = np.array(X), np.array(y)

# LSTM model
model = Sequential()
model.add(LSTM(50, input_shape=(X.shape[1], 1)))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')
model.fit(X, y, epochs=5)
# Out:
# Epoch 1/5
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 3014/3014 ━━━━━━━━━━━━━━━━━━━━ 23s 7ms/step - loss: 0.0026
# Epoch 2/5
# 3014/3014 ━━━━━━━━━━━━━━━━━━━━ 19s 6ms/step - loss: 5.9064e-04
# Epoch 3/5
# 3014/3014 ━━━━━━━━━━━━━━━━━━━━ 20s 7ms/step - loss: 5.5962e-04
# Epoch 4/5
# 3014/3014 ━━━━━━━━━━━━━━━━━━━━ 20s 6ms/step - loss: 5.4409e-04
# Epoch 5/5
# 3014/3014 ━━━━━━━━━━━━━━━━━━━━ 21s 7ms/step - loss: 5.4207e-04
