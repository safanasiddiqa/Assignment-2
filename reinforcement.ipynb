# %%
# STEP 1: Import required libraries
import gym
import numpy as np
# STEP 2: Create Taxi-v3 environment
env = gym.make("taxi-v3")
# STEP 3: Initialize Q-table
state_size = env.observation_space.n
action_size = env.action_space.n

q_table = np.zeros((state_size, action_size))
# STEP 4: Define hyperparameters
alpha = 0.1      # Learning rate
gamma = 0.6      # Discount factor
epsilon = 0.1    # Exploration rate
episodes = 1000
# STEP 5: Train the agent using Q-Learning
for episode in range(episodes):
    state = env.reset()
    done = False

    while not done:
        # Exploration vs exploitation
        if np.random.uniform(0, 1) < epsilon:
            action = env.action_space.sample()
        else:
            action = np.argmax(q_table[state])

        next_state, reward, done, info = env.step(action)

        # Q-learning update rule
        q_table[state, action] = q_table[state, action] + alpha * (
            reward + gamma * np.max(q_table[next_state]) - q_table[state, action]
        )

        state = next_state

# STEP 6: Test the trained agent
state = env.reset()
done = False

print("Testing trained Taxi agent...\n")

while not done:
    action = np.argmax(q_table[state])
    state, reward, done, info = env.step(action)
    env.render()
# STEP 7: Close environment
env.close()
# Out:
# ---------------------------------------------------------------------------
# NameNotFound                              Traceback (most recent call last)
# /tmp/ipykernel_6571/3754139219.py in <cell line: 0>()
#       3 import numpy as np
#       4 # STEP 2: Create Taxi-v3 environment
# ----> 5 env = gym.make("taxi-v3")
#       6 # STEP 3: Initialize Q-table
#       7 state_size = env.observation_space.n
#
# /usr/local/lib/python3.12/dist-packages/gym/envs/registration.py in make(id, max_episode_steps, autoreset, new_step_api, disable_env_checker, **kwargs)
#     605
#     606         if spec_ is None:
# --> 607             _check_version_exists(ns, name, version)
#     608             raise error.Error(f"No registered env with id: {id}")
#     609
#
# /usr/local/lib/python3.12/dist-packages/gym/envs/registration.py in _check_version_exists(ns, name, version)
#     232         return
#     233
# --> 234     _check_name_exists(ns, name)
#     235     if version is None:
# ...
